# %% [markdown]
# # Appendix: Useful Examples for Climate Analysis
#
# (Updating. Most of the examples are currently in Mandarin. Will be translated into English in the near future. )
#
# - [Select data with irregular grid.](https://wyhtsai.github.io/pyaos_eng/docs/A4_ireg_grid_sel.html)
#
# ## Climate Variability Analysis
# - [1-dimensional spectural analysis](https://wyhtsai.github.io/pyaos_eng/docs/A7_power_spec_py.html)
# - [Lanczos filtering](https://wyhtsai.github.io/pyaos_eng/docs/A3_lanczos_filter.html)。
# - [MJO phase diagram](https://wyhtsai.github.io/pyaos_eng/docs/A1_mjo_phase.html)。
# - [MJO phase composite and significance test](https://wyhtsai.github.io/pyaos_eng/docs/A1_mjo_phase.html#mjo-composite)。
# - [Analysis and filtering the convectively coupled equatorial waves (CCEWs)](https://wyhtsai.github.io/pyaos_eng/docs/A6_tropical_waves.html)。
