# %% [markdown]
# # 12. 優化作業流程：`dask`

# %%
from dask.distributed import Client
import xarray as xr

client = Client(n_workers=4, threads_per_worker=2, memory_limit='4GB')
client
# Out:
# /Users/waynetsai/opt/anaconda3/envs/p3/lib/python3.9/site-packages/distributed/node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 49769 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:49770' processes=4 threads=8, memory=14.90 GiB>
